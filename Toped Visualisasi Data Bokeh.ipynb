# %% [markdown]
# <a href="https://colab.research.google.com/github/irwanmaulana42/google-collab/blob/master/Toped%20Visualisasi%20Data%20Bokeh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paling rating terbaik dan terburuk kaa, sm topik makanan yang paling banyak dicari

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.palettes import Category10_10
# Out:
#   <div class="bk-root" id="ef8e4c16-717e-43f6-b6e2-b3b4698374eb" data-root-id="1003"></div>

# %%
# Data ulasan produk makanan
reviews = {
    'produk': ['Produk A', 'Produk B', 'Produk C', 'Produk D', 'Produk E'],
    'rating': [4.2, 3.8, 4.5, 3.5, 4.0],
    'ulasan': [25, 30, 20, 15, 35]
}

# Membuat ColumnDataSource dari data
source = ColumnDataSource(reviews)

# Membuat output notebook
output_notebook()

# Membuat plot
p = figure(x_range=reviews['produk'], plot_height=400, title='Ulasan Produk Makanan',
           toolbar_location=None, tools="")

# Menambahkan batang untuk rating
p.vbar(x='produk', top='rating', width=0.9, source=source, color=Category10_10[0],
       legend_label='Rating')

# Menambahkan batang untuk jumlah ulasan
p.vbar(x='produk', top='ulasan', width=0.9, source=source, color=Category10_10[1],
       legend_label='Jumlah Ulasan')

# Menambahkan hover tool
hover = HoverTool(tooltips=[('Produk', '@produk'), ('Rating', '@rating'),
                            ('Jumlah Ulasan', '@ulasan')])
p.add_tools(hover)

# Mengatur sumbu x dan y
p.xgrid.grid_line_color = None
p.y_range.start = 0

# Menampilkan plot
show(p)

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
from bokeh.models import HoverTool
from bokeh.palettes import Spectral6

# Mengambil dataset dari URL
url = 'https://raw.githubusercontent.com/irwanmaulana42/google-collab/master/dataset_review_tokped_labelled.csv'
data = pd.read_csv(url)

# Menghitung jumlah ulasan positif dan negatif
counts = data['Sentiment'].value_counts()
labels = counts.index.tolist()
print(counts)
jumlah = counts.tolist()

# Membuat output notebook
output_notebook()

# Membuat plot
p = figure(x_range=labels, plot_height=400, title='Jumlah Ulasan Positif dan Negatif',
           toolbar_location=None, tools="")

# Menambahkan batang untuk jumlah ulasan
p.vbar(x=labels, top=jumlah, width=0.5, color=Spectral6[:3])

# Menambahkan hover tool
hover = HoverTool(tooltips=[('Label', '@x'), ('Jumlah', '@top')])
p.add_tools(hover)

# Mengatur sumbu x dan y
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = max(jumlah) + 100

# Menampilkan plot
show(p)
# Out:
# positive    2903
# neutral      585
# negative     572
# Name: Sentiment, dtype: int64
#   <div class="bk-root" id="55b228ac-41e8-4b33-a88a-8991345454ca" data-root-id="1546"></div>

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# Mengambil dataset dari URL
url = 'https://raw.githubusercontent.com/irwanmaulana42/google-collab/master/dataset_review_tokped_labelled.csv'
data = pd.read_csv(url)

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menghitung banyaknya review per rating
review_counts = df['Rating'].value_counts().sort_index()

# Membuat output notebook
output_notebook()

# Membuat plot
p = figure(x_range=[str(rating) for rating in review_counts.index], plot_height=400, title='Banyaknya Review per Rating',
           toolbar_location=None, tools="")

# Menambahkan batang untuk jumlah review
p.vbar(x=[str(rating) for rating in review_counts.index], top=review_counts.values, width=0.5, color='steelblue')

# Menambahkan hover tool
hover = HoverTool(tooltips=[('Label', '@x'), ('Jumlah', '@top')])
p.add_tools(hover)

# Mengatur sumbu x dan y
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = max(review_counts.values) + 1

# Menampilkan plot
show(p)
# Out:
#   <div class="bk-root" id="3468ead0-768b-4ffb-bf81-d069bc79598f" data-root-id="2214"></div>

# %%
import pandas as pd
from collections import Counter
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# Dataset
# Mengambil dataset dari URL
url = 'https://raw.githubusercontent.com/irwanmaulana42/google-collab/master/dataset_review_tokped_labelled.csv'
data = pd.read_csv(url)

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menggabungkan semua review menjadi satu teks
all_reviews = ' '.join(df['Review'])

# Menghitung kemunculan kata menggunakan Counter
word_counts = Counter(all_reviews.split())

# Mengambil 10 kata terbanyak
top_10_words = word_counts.most_common(10)
words = [word[0] for word in top_10_words]
counts = [count[1] for count in top_10_words]

# Membuat output notebook
output_notebook()

# Membuat plot
p = figure(x_range=words, plot_height=400, title='Kata yang Paling Sering Muncul',
           toolbar_location=None, tools="")

# Menambahkan hover tool
hover = HoverTool(tooltips=[('Label', '@x'), ('Jumlah', '@top')])
p.add_tools(hover)

# Menambahkan batang untuk jumlah kemunculan kata
p.vbar(x=words, top=counts, width=0.5, color='green')

# Mengatur sumbu x dan y
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = max(counts) + 1

# Menampilkan plot
show(p)
# Out:
#   <div class="bk-root" id="201349bd-9d34-4e67-85fd-fd82ef7a11cf" data-root-id="2545"></div>

# %%
# !pip install Sastrawi

# %%
import pandas as pd
from collections import Counter
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Dataset
# Mengambil dataset dari URL
url = 'https://raw.githubusercontent.com/irwanmaulana42/google-collab/master/dataset_review_tokped_labelled.csv'
data = pd.read_csv(url)

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menggabungkan semua review menjadi satu teks
all_reviews = ' '.join(df['Review'])

# Melakukan stemming dengan Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()
stemmed_text = stemmer.stem(all_reviews)

# Tokenisasi teks menjadi kata-kata
tokens = stemmed_text.split()

# Menghitung kemunculan kata menggunakan Counter
word_counts = Counter(tokens)

# %%
# Mengambil 10 kata terbanyak
top_10_words = word_counts.most_common(20)
words = [word[0] for word in top_10_words]
counts = [count[1] for count in top_10_words]

# Membuat output notebook
output_notebook()

# Membuat plot
p = figure(x_range=words, plot_height=400, plot_width=800, title='Kata yang Paling Sering Muncul (Setelah Stemming)',
           toolbar_location=None, tools="")

# Menambahkan batang untuk jumlah kemunculan kata
p.vbar(x=words, top=counts, width=0.5, color='green')

# Menambahkan hover tool
hover = HoverTool(tooltips=[('Label', '@x'), ('Jumlah', '@top')])
p.add_tools(hover)

# Mengatur sumbu x dan y
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = max(counts) + 1

# Menampilkan plot
show(p)
# Out:
#   <div class="bk-root" id="d6a7e980-06b4-4535-b69e-af3a0ac376a5" data-root-id="3525"></div>

# %%
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# Dataset
data = {
    'review': [
        'enak kuacinya',
        'pengiriman cepat packing bagus sesuai pesanan belum di coba terima kasih',
        'pengemasan luar biasa baik untuk rasa menurut saya lebih dominan ke rasa original',
        'terimakasih min',
        'udah order untuk kesekian kali jos',
        'enaak dan guriih kacangnya',
        'respon cepat harga terjangkau'
    ],
    'rating': [5, 5, 4, 5, 5, 5, 5],
    'sentiment': ['positive', 'positive', 'negative', 'neutral', 'neutral', 'positive', 'positive']
}

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menghitung jumlah sentimen
sentiment_counts = df['sentiment'].value_counts()

# Membuat output notebook
output_notebook()

# Membuat plot bar chart
p = figure(x_range=sentiment_counts.index.tolist(), plot_height=400, title='Distribusi Sentimen', toolbar_location=None, tools="")

# Menambahkan batang untuk jumlah sentimen
p.vbar(x=sentiment_counts.index.tolist(), top=sentiment_counts.values.tolist(), width=0.5, color='steelblue')

# Mengatur sumbu x dan y
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = max(sentiment_counts.values) + 1

# Menampilkan plot
show(p)
# Out:
#   <div class="bk-root" id="86d87cca-5f02-4592-b352-cef97317ceb8" data-root-id="4003"></div>

# %%
import pandas as pd
from collections import Counter
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Dataset
# Mengambil dataset dari URL
url = 'https://raw.githubusercontent.com/irwanmaulana42/google-collab/master/dataset_review_tokped_labelled.csv'
data = pd.read_csv(url)

# Membuat DataFrame dari data
df = pd.DataFrame(data)

# Menggabungkan semua review menjadi satu teks
all_reviews = ' '.join(df['Review'])

# Melakukan stemming dengan Sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()
stemmed_text = stemmer.stem(all_reviews)

# Menghapus stopwords dengan Sastrawi
stopword_factory = StopWordRemoverFactory()
stopwords = stopword_factory.get_stop_words()
stopwords = set(stopwords) # Mengubah menjadi set untuk efisiensi

# Tokenisasi teks menjadi kata-kata
tokens = stemmed_text.split()

# Menghapus stopwords dari token
filtered_tokens = [token for token in tokens if token not in stopwords]

# Menghitung kemunculan kata menggunakan Counter
word_counts = Counter(filtered_tokens)

# %%
# Mengambil 10 kata terbanyak
top_10_words = word_counts.most_common(100)
words = [word[0] for word in top_10_words]
counts = [count[1] for count in top_10_words]

# Membuat output notebook
output_notebook()

# Membuat plot
p = figure(x_range=words, plot_height=400, plot_width=5000, title='Kata yang Paling Sering Muncul (Setelah Stemming dan Stopwords Removal)',
           toolbar_location=None, tools="")

# Menambahkan batang untuk jumlah kemunculan kata
p.vbar(x=words, top=counts, width=0.5, color='green')

# Menambahkan hover tool
hover = HoverTool(tooltips=[('Label', '@x'), ('Jumlah', '@top')])
p.add_tools(hover)

# Mengatur sumbu x dan y
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.y_range.end = max(counts) + 1

# Menampilkan plot
show(p)
# Out:
#   <div class="bk-root" id="39fc7051-bc31-49e7-a671-5d9f16d3672d" data-root-id="7505"></div>
